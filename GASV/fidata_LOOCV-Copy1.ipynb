# %%
# %load LOOCV.py
# %matplotlib
from matplotlib import pyplot as plt
import lasio
from sklearn import preprocessing
import numpy as np
np.set_printoptions(threshold=np.inf)
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import openpyxl
from sklearn.svm import SVR
from sklearn.model_selection import LeaveOneOut
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn import tree
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
import random
from matplotlib.font_manager import *
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: TkAgg

# %%
from model import one_cnn_model, three_cnn_model, bp_model, LinearRegression_model1, LinearRegression_model2
import model
import imp
imp.reload(model)
from model import one_cnn_model, three_cnn_model, bp_model, LinearRegression_model1, LinearRegression_model2

# %%
from DataSet import dataset_lab
import DataSet
import imp
imp.reload(DataSet)
from DataSet import dataset_lab

# %%
from Normalization import Normalization, Anti_Normalization, Normalization_lab, Anti_Normalization_lab
import Normalization
import imp
imp.reload(Normalization)
from Normalization import Normalization, Anti_Normalization, Normalization_lab, Anti_Normalization_lab

# %%
# 读取初始化相关数据
b = 6

# %% [markdown]
# data = dataset_lab(b)

# %% [markdown]
# 保存[DTS, DT, RHOB, GR, GAS(real), GAS(log))

# %% [markdown]
# np.savetxt(r"C:\Users\Administrator\Projects\LongMaXi\unShuffle_data",data)

# %%
#画热力图
a=pd.DataFrame(data[:,0:-1]).corr()
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(9, 9))
sns.heatmap(a, annot=True, vmax=1, square=True, cmap="Blues", xticklabels=False, yticklabels=False, annot_kws={'size':12})
plt.show()

# %%
data = np.loadtxt(r"C:\Users\Administrator\Projects\LongMaXi\unShuffle_data")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-5688ff7255bd> in <module>()
# ----> 1 data = np.loadtxt(r"C:\Users\Administrator\Projects\LongMaXi\unShuffle_data")
#
# D:\software\anaconda\envs\tensorflow\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# D:\software\anaconda\envs\tensorflow\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# D:\software\anaconda\envs\tensorflow\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: C:\Users\Administrator\Projects\LongMaXi\unShuffle_data not found.

# %%
shuffle_data = data[:,[0,1,2, 4, 5]]
print(shuffle_data.shape)
# Out:
# (201, 5)

# %%
np.random.shuffle(shuffle_data)
print(shuffle_data.shape)
# Out:
# (201, 5)

# %%
model = LinearRegression()
shuffle_RHOB = shuffle_data[:, 2].reshape(-1, 1)
shuffle_GAS = shuffle_data[:, 3].reshape(-1, 1)
model.fit(shuffle_RHOB, shuffle_GAS)
score = model.score(shuffle_RHOB, shuffle_GAS)
ev = model.coef_  # 回归系数
inter = model.intercept_
shuffle_LR_GAS = model.predict(shuffle_RHOB).reshape(-1, 1)
#     print("yhat:", yhat)
#     print("yhat_array[test_index][0]:", yhat_array[test_index][0])
print("ev:", ev)
print("inter:", inter)
# Out:
# ev: [[-10.56499268]]
# inter: [29.40776038]

# %%
Onefil_data = []
b = 1.6
for i in range(shuffle_data.shape[0]):
    if(-b< (shuffle_GAS[i] - shuffle_LR_GAS[i]) < b):
        Onefil_data.append(shuffle_data[i])
Onefil_data = np.array(Onefil_data)
print(Onefil_data.shape)
# Out:
# (179, 5)

# %%
Onefil_NL_data = Normalization_lab(Onefil_data)
# Out:
# (179, 5)

# %%
#画热力图
a=pd.DataFrame(Onefil_NL_data[:,0:-1]).corr()
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(9, 9))
sns.heatmap(a, annot=True, vmax=1, square=True, cmap="Blues", xticklabels=False, yticklabels=False, annot_kws={'size':12})
plt.show()

# %%
cnn

# %% [markdown]
# cnn

# %%
loo = LeaveOneOut()
Onefil_cnn =[]
Onefil_NL_input_data = Onefil_NL_data[:, 0: 3].reshape(-1, 1, 3)
Onefil_NL_output_data = Onefil_NL_data[:, 3].reshape(-1, 1, 1)
loo.get_n_splits(Onefil_NL_input_data)
for train_index, test_index in loo.split(Onefil_NL_input_data):
    NL_train_X_data, NL_test_X_data = Onefil_NL_input_data[train_index], Onefil_NL_input_data[test_index]
    NL_train_Y_data, NL_test_Y_data = Onefil_NL_output_data[train_index], Onefil_NL_output_data[test_index]
    Onefil_yhat, model, history = three_cnn_model(NL_train_X_data, NL_train_Y_data, NL_test_X_data, NL_test_Y_data, 32)
    NL_test_X_data = NL_test_X_data.reshape(1,-1)
    Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat, Onefil_NL_data[2,-1].reshape(-1, 1))
    Onefil_cnn.append(Onefil_yhat)
Onefil_cnn = np.array(Onefil_cnn)
# Out:
# Model: "sequential_717"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1436 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1437 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_718 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1438 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1439 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_719 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_359 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1434 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1435 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A27C8B730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_718"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1440 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1441 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_720 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1442 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1443 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_721 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_360 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1436 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1437 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A39732840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_719"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1444 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1445 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_722 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1446 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1447 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_723 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_361 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1438 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1439 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000268FE12A048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_720"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1448 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1449 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_724 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1450 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1451 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_725 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_362 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1440 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1441 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3ACE6C80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_721"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1452 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1453 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_726 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1454 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1455 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_727 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_363 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1442 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1443 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A456DBAE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_722"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1456 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1457 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_728 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1458 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1459 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_729 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_364 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1444 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1445 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A478D3950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_723"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1460 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1461 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_730 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1462 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1463 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_731 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_365 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1446 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1447 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2D98D1E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_724"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1464 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1465 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_732 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1466 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1467 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_733 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_366 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1448 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1449 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000269F6FA1840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_725"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1468 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1469 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_734 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1470 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1471 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_735 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_367 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1450 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1451 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3BDAA598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_726"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1472 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1473 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_736 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1474 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1475 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_737 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_368 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1452 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1453 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3E47EAE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_727"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1476 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1477 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_738 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1478 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1479 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_739 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_369 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1454 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1455 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A02ACF048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_728"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1480 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1481 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_740 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1482 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1483 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_741 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_370 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1456 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1457 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DC348C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_729"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1484 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1485 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_742 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1486 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1487 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_743 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_371 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1458 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1459 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E16F9D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_730"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1488 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1489 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_744 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1490 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1491 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_745 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_372 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1460 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1461 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3BDAEF28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_731"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1492 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1493 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_746 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1494 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1495 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_747 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_373 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1462 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1463 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A37452268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_732"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1496 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1497 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_748 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1498 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1499 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_749 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_374 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1464 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1465 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A456DB7B8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_733"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1500 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1501 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_750 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1502 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1503 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_751 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_375 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1466 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1467 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2A445D08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_734"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1504 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1505 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_752 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1506 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1507 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_753 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_376 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1468 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1469 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3AC4FC80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_735"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1508 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1509 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_754 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1510 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1511 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_755 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_377 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1470 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1471 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A27C8B9D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_736"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1512 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1513 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_756 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1514 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1515 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_757 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_378 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1472 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1473 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3E425E18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_737"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1516 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_1517 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_758 (MaxPoolin (None, 32, 2)             0
# _________________________________________________________________
# conv1d_1518 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_1519 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_759 (MaxPoolin (None, 64, 1)             0
# _________________________________________________________________
# flatten_379 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1474 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1475 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# ...
# conv1d_2124 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2125 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1062 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2126 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2127 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1063 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_531 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1778 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1779 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A492919D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_890"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2128 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2129 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1064 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2130 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2131 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1065 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_532 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1780 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1781 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E7B82F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_891"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2132 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2133 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1066 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2134 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2135 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1067 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_533 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1782 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1783 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A43EC7E18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_892"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2136 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2137 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1068 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2138 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2139 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1069 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_534 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1784 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1785 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3F6459D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_893"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2140 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2141 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1070 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2142 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2143 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1071 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_535 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1786 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1787 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A48C078C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_894"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2144 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2145 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1072 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2146 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2147 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1073 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_536 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1788 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1789 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A41BC3BF8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "sequential_895"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2148 (Conv1D)         (None, 32, 3)             96
# _________________________________________________________________
# conv1d_2149 (Conv1D)         (None, 32, 3)             2080
# _________________________________________________________________
# max_pooling1d_1074 (MaxPooli (None, 32, 2)             0
# _________________________________________________________________
# conv1d_2150 (Conv1D)         (None, 64, 2)             4160
# _________________________________________________________________
# conv1d_2151 (Conv1D)         (None, 64, 2)             8256
# _________________________________________________________________
# max_pooling1d_1075 (MaxPooli (None, 64, 1)             0
# _________________________________________________________________
# flatten_537 (Flatten)        (None, 64)                0
# _________________________________________________________________
# dense_1790 (Dense)           (None, 30)                1950
# _________________________________________________________________
# dense_1791 (Dense)           (None, 1)                 31
# =================================================================
# Total params: 16,573
# Trainable params: 16,573
# Non-trainable params: 0
# _________________________________________________________________
#
#  None
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A44FE3950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# bp

# %%
Onefil_NL_input_data = Onefil_NL_data[:, 0: 3].reshape(-1, 1, 3)
Onefil_NL_output_data = Onefil_NL_data[:, 3].reshape(-1, 1, 1)
loo.get_n_splits(Onefil_NL_input_data)
Onefil_bp =[]
for train_index, test_index in loo.split(Onefil_NL_input_data):
    NL_train_X_data, NL_test_X_data = Onefil_NL_input_data[train_index], Onefil_NL_input_data[test_index]
    NL_train_Y_data, NL_test_Y_data = Onefil_NL_output_data[train_index], Onefil_NL_output_data[test_index]
    Onefil_yhat, model, history = bp_model(NL_train_X_data, NL_train_Y_data, NL_test_X_data, NL_test_Y_data)
    NL_test_X_data = NL_test_X_data.reshape(1,-1)
    Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat,Onefil_NL_data[2,-1].reshape(-1, 1))
    Onefil_bp.append(Onefil_yhat)
Onefil_bp= np.array(Onefil_bp).reshape(-1, 1)
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3F5D4BF8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A37281D90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49341E18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4933F268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A48F987B8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A48C111E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E87A9D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A493AB048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49C32488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A02C268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A10D730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DC8C158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A10D0D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DE2D1E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DF16400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DE76950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A48C11BF8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A41A59840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E95A268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A37452950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4083BD08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3F679268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3CFA6C80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000268FDCC4598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A41C95950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A42E03D90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E97A8C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DE2DEA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A149840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49C32730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A218C30D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A48EB8950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49341AE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2ED242F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4933FE18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A491E1158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2EEB5620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A43F86730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2189CD90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49247950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000269F6FA1488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E5B4D08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49E61E18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DFF02F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DD7A268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49E732F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A218952F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49CDA2F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A068378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A48D31378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2DDD3378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A0F0400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A0C3400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E045400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A28B488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A5B845488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A5C87A488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3D1B7D08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49BCAE18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A43F86C80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2F0462F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2ED24F28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A5EE86B70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A5EF1C598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3D1B7510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A494A0EA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3BDAEF28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49E73BF8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A068950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2E2789D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A070BF8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2EC63378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A28BE18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49D2C950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4A0B9EA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A397BFEA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2EDFAE18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A2D965E18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3AC38C80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A49291730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A4933FAE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A43EABEA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# rf

# %%
Onefil_NL_input_data = Onefil_NL_data[:, 0:3]
print(Onefil_NL_input_data.shape)
Onefil_NL_output_data = Onefil_NL_data[:,3]
# Out:
# (179, 3)

# %%
x_len = Onefil_NL_input_data.shape[1]

# %%
loo = LeaveOneOut()
loo.get_n_splits(Onefil_NL_input_data)
Onefil_rf =[]
for train_index, test_index in loo.split(Onefil_NL_input_data):
    NL_train_X_data, NL_test_X_data = Onefil_NL_input_data[train_index], Onefil_NL_input_data[test_index]
    NL_train_Y_data, NL_test_Y_data = Onefil_NL_output_data[train_index], Onefil_NL_output_data[test_index]

    NL_train_X_data, NL_test_X_data = NL_train_X_data.reshape(-1, x_len), NL_test_X_data.reshape(-1, x_len)
    NL_test_X_data = NL_test_X_data.reshape(-1, x_len)
    rfr = RandomForestRegressor(n_estimators = 128, min_samples_leaf = 14, random_state=13)
    Onefil_yhat = rfr.fit(NL_train_X_data,NL_train_Y_data).predict(NL_test_X_data).reshape(-1, 1)

    Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat, Onefil_NL_data[2,-1].reshape(-1, 1))
    Onefil_rf.append(Onefil_yhat)
Onefil_rf= np.array(Onefil_rf).reshape(-1, 1)
print(Onefil_rf.shape)
# Out:
# (179, 1)

# %% [markdown]
# DT

# %%
loo = LeaveOneOut()
loo.get_n_splits(Onefil_NL_input_data)
Onefil_dt =[]
for train_index, test_index in loo.split(Onefil_NL_input_data):
    NL_train_X_data, NL_test_X_data = Onefil_NL_input_data[train_index], Onefil_NL_input_data[test_index]
    NL_train_Y_data, NL_test_Y_data = Onefil_NL_output_data[train_index], Onefil_NL_output_data[test_index]

    NL_train_X_data, NL_test_X_data = NL_train_X_data.reshape(-1, x_len), NL_test_X_data.reshape(-1, x_len)
    NL_test_X_data = NL_test_X_data.reshape(-1, x_len)
    dtr = tree.DecisionTreeRegressor(max_depth = 20, min_samples_leaf = 20, random_state=13)
    Onefil_yhat = dtr.fit(NL_train_X_data, NL_train_Y_data).predict(NL_test_X_data).reshape(-1, 1)

    Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat,Onefil_NL_data[2,-1].reshape(-1, 1))
    Onefil_dt.append(Onefil_yhat)
Onefil_dt= np.array(Onefil_dt).reshape(-1, 1)

# %% [markdown]
# SVR

# %%
loo = LeaveOneOut()
loo.get_n_splits(Onefil_NL_input_data)
Onefil_svr =[]
for train_index, test_index in loo.split(Onefil_NL_input_data):
    NL_train_X_data, NL_test_X_data = Onefil_NL_input_data[train_index], Onefil_NL_input_data[test_index]
    NL_train_Y_data, NL_test_Y_data = Onefil_NL_output_data[train_index], Onefil_NL_output_data[test_index]

    NL_train_X_data, NL_test_X_data = NL_train_X_data.reshape(-1, x_len), NL_test_X_data.reshape(-1,x_len)
    NL_test_X_data = NL_test_X_data.reshape(-1, x_len)
    svr_rbf = SVR(kernel='rbf', C=1e2, gamma = 0.4)
    Onefil_yhat = svr_rbf.fit(NL_train_X_data, NL_train_Y_data).predict(NL_test_X_data).reshape(-1, 1)
    Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat, Onefil_NL_data[2,-1].reshape(-1, 1))
    # Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat)
    Onefil_svr.append(Onefil_yhat)
#     print("yhat:", yhat)
#     print("yhat_array[test_index][0]:", yhat_array[test_index][0])
Onefil_svr= np.array(Onefil_svr).reshape(-1, 1)
print(Onefil_svr.shape)
# Out:
# (179, 1)

# %%
print(Onefil_svr)
# Out:
# [[ 0.56090568]
#  [ 0.28843033]
#  [ 1.71521853]
#  [ 3.36632795]
#  [ 1.92882423]
#  [ 3.38253538]
#  [ 2.20764773]
#  [ 5.21866301]
#  [ 3.11397503]
#  [ 2.67267537]
#  [ 2.38826828]
#  [ 3.86739008]
#  [ 2.01627534]
#  [ 0.91417188]
#  [ 1.46069291]
#  [ 2.34097788]
#  [ 1.96921572]
#  [ 2.16314448]
#  [ 1.03149208]
#  [ 3.5022595 ]
#  [ 1.94041696]
#  [ 4.15207546]
#  [ 2.31182218]
#  [ 2.32440201]
#  [ 3.91495223]
#  [-0.03375214]
#  [ 4.17053046]
#  [ 2.3926351 ]
#  [ 2.73932478]
#  [ 2.42309285]
#  [ 2.00586607]
#  [ 0.2257898 ]
#  [ 3.67812836]
#  [ 2.61947937]
#  [ 0.43426083]
#  [ 0.85176439]
#  [ 2.38205128]
#  [ 0.74214117]
#  [ 3.4186737 ]
#  [ 1.70816878]
#  [ 0.86685715]
#  [ 0.11623341]
#  [ 1.6094211 ]
#  [ 3.09176465]
#  [ 1.5924136 ]
#  [ 0.23005385]
#  [ 2.58840808]
#  [ 2.59999874]
#  [ 2.49863911]
#  [ 2.52181846]
#  [ 2.36869412]
#  [ 2.98582328]
#  [ 4.53401386]
#  [ 0.82510712]
#  [ 2.41730009]
#  [ 2.20590768]
#  [ 2.87378266]
#  [ 2.30807081]
#  [ 2.91232758]
#  [ 2.22821858]
#  [ 1.59730839]
#  [ 1.89565173]
#  [ 2.03218794]
#  [ 1.7457787 ]
#  [ 1.1590686 ]
#  [ 2.76389711]
#  [ 2.82147424]
#  [ 4.36960083]
#  [ 1.7659632 ]
#  [ 1.63726297]
#  [ 2.54244554]
#  [ 2.75387796]
#  [ 0.47682204]
#  [ 2.89362307]
#  [ 1.5166379 ]
#  [ 3.24759713]
#  [ 0.55391777]
#  [ 4.62869789]
#  [ 2.08707882]
#  [ 2.43452141]
#  [ 2.32191084]
#  [ 0.95627784]
#  [ 2.77840132]
#  [ 2.68664708]
#  [ 2.54769691]
#  [ 0.52996613]
#  [ 2.29233694]
#  [ 3.88837523]
#  [ 3.16898287]
#  [ 1.79421543]
#  [ 2.46485076]
#  [ 1.13486118]
#  [ 4.33957285]
#  [ 2.40351749]
#  [ 2.10754646]
#  [ 2.48840736]
#  [ 1.07264561]
#  [ 3.55074658]
#  [ 2.2098625 ]
#  [ 2.89707369]
#  [ 3.45096302]
#  [ 2.90542316]
#  [ 1.60720025]
#  [ 1.58220048]
#  [ 3.33779018]
#  [ 3.0096412 ]
#  [ 2.84924547]
#  [ 2.29879831]
#  [ 0.62377345]
#  [ 1.66878974]
#  [ 4.12205113]
#  [ 2.32456752]
#  [ 2.39099157]
#  [ 2.15759427]
#  [ 1.09366172]
#  [ 0.54769867]
#  [ 3.09251043]
#  [ 1.0095244 ]
#  [ 1.26013322]
#  [ 1.29592186]
#  [ 2.32943408]
#  [ 1.353474  ]
#  [ 2.12974796]
#  [ 2.11551841]
#  [ 1.35648019]
#  [ 0.38526591]
#  [ 3.09577516]
#  [ 2.08237614]
#  [ 2.57879046]
#  [ 1.96587571]
#  [ 3.03997762]
#  [ 3.19127671]
#  [ 3.98083282]
#  [ 1.11499149]
#  [ 2.3442058 ]
#  [ 4.27164393]
#  [ 1.62203221]
#  [ 2.52040741]
#  [ 2.62015309]
#  [ 1.69074547]
#  [ 3.81787948]
#  [ 2.31759355]
#  [ 2.4971394 ]
#  [ 1.33031206]
#  [ 2.70189874]
#  [ 2.75025352]
#  [ 2.0333934 ]
#  [ 2.91424479]
#  [ 0.50002087]
#  [ 3.55726295]
#  [ 2.73856923]
#  [ 2.93987378]
#  [ 0.61286414]
#  [ 0.96264846]
#  [ 0.80171515]
#  [ 2.07267461]
#  [ 3.03384206]
#  [ 1.94582256]
#  [ 2.46833941]
#  [ 1.24377404]
#  [ 1.80602929]
#  [ 3.12804027]
#  [ 2.43679141]
#  [ 2.85759174]
#  [ 2.72566467]
#  [ 1.59574803]
#  [ 0.7865985 ]
#  [ 0.26438592]
#  [ 2.75571177]
#  [ 0.55534594]
#  [ 0.53642784]
#  [ 2.57683179]
#  [ 1.41955195]
#  [ 2.40459934]
#  [ 2.88333785]
#  [ 2.55905539]
#  [ 0.01899861]
#  [ 3.23881283]
#  [ 2.23879044]]

# %%
excel = np.hstack(((Onefil_data[:,3]).reshape(-1,1),Onefil_svr, Onefil_dt, Onefil_rf, 
                  Onefil_bp.reshape(-1,1), Onefil_cnn.reshape(-1, 1)))
print(excel)
# Out:
# [[ 0.4667      0.56090568  0.54235493  0.60854014  0.31635404  0.4902363 ]
#  [ 0.31        0.28843033  0.54795136  0.60060659  0.57319949  0.3164592 ]
#  [ 0.6164      1.71521853  1.36306512  1.60569935  1.75528966  2.04172711]
#  [ 2.7         3.36632795  3.79417039  3.77796681  3.43520107  3.39185067]
#  [ 0.86711825  1.92882423  2.14277737  2.16128255  2.61103656  2.72952201]
#  [ 2.91        3.38253538  3.78667039  3.75869678  3.35556068  3.19243269]
#  [ 2.28356167  2.20764773  2.34317677  2.14608587  2.3626722   2.22083026]
#  [ 3.9         5.21866301  3.75131324  3.75685506  4.38332743  5.27307175]
#  [ 4.32633246  3.11397503  3.73608709  3.34299076  3.08838432  3.30082977]
#  [ 3.12        2.67267537  2.82471756  2.72306769  2.69029774  2.81503759]
#  [ 2.30508386  2.38826828  2.54684182  2.330354    2.59747537  2.71850896]
#  [ 3.82588478  3.86739008  3.75396022  3.73489008  3.75445388  3.57546473]
#  [ 1.63673935  2.01627534  1.32527477  1.76547908  2.13367736  1.73713774]
#  [ 3.88517228  3.12804027  3.75184281  3.4620488   3.15226687  3.25177647]
#  [ 2.66        2.43679141  2.10132367  2.06111699  2.04128781  2.2786212 ]
#  [ 2.69853242  2.85759174  2.83876648  2.82255933  2.83081411  2.84143138]
#  [ 3.72524088  2.72566467  2.80454286  2.74028393  2.71459578  2.41271178]
#  [ 2.20887591  1.59574803  2.04423579  1.62104555  1.6586035   1.53273446]
#  [ 0.46223811  0.7865985   0.54251429  0.57997383  0.61189256  1.12718815]
#  [ 0.3251      0.26438592  0.54741208  0.56675955  0.1589587   0.74602927]
#  [ 2.24002492  2.75571177  2.85405006  2.91134947  2.80171435  3.10936857]
#  [ 0.43466009  0.55534594  0.54349922  0.57783983  0.68427876  0.190043  ]
#  [ 0.52581849  0.53642784  0.54024356  0.57304336  0.40591126  0.68695171]
#  [ 3.44        2.57683179  2.49022032  2.61705971  2.8070275   2.57727333]
#  [ 0.962634    1.41955195  1.35024163  1.47758046  1.32350943  1.21227836]
#  [ 3.03        2.40459934  2.30585486  2.40492875  2.19608463  2.1001819 ]
#  [ 3.8         2.88333785  2.80205089  2.73345657  2.82747622  2.95010466]
#  [ 2.7328712   2.55905539  2.83762185  2.79579351  2.89348222  2.55009718]
#  [ 1.6392      0.01899861  2.58026032  2.66598914  1.28554613  2.2847238 ]
#  [ 2.65        3.23881283  3.7959561   3.7746383   3.13350035  3.02978059]
#  [ 2.1527022   2.23879044  2.34971975  2.20359941  2.30425973  2.20736439]]

# %% [markdown]
# LR

# %%
loo = LeaveOneOut()
loo.get_n_splits(Onefil_NL_input_data)
Onefil_lr =[]
for train_index, test_index in loo.split(Onefil_NL_input_data):
    NL_train_X_data, NL_test_X_data = Onefil_NL_input_data[train_index], Onefil_NL_input_data[test_index]
    NL_train_Y_data, NL_test_Y_data = Onefil_NL_output_data[train_index], Onefil_NL_output_data[test_index]

    NL_train_X_data, NL_test_X_data = NL_train_X_data.reshape(-1, x_len), NL_test_X_data.reshape(-1, x_len)
    NL_test_X_data = NL_test_X_data.reshape(-1, x_len)
    Onefil_yhat, model, score, ev  = LinearRegression_model1(NL_train_X_data, NL_train_Y_data, NL_test_X_data, NL_test_Y_data)
    Onefil_yhat = Anti_Normalization_lab(Onefil_data, NL_test_X_data, Onefil_yhat, Onefil_NL_data[2,-1].reshape(-1, 1))
    Onefil_lr.append(Onefil_yhat)
#     print("yhat:", yhat)
#     print("yhat_array[test_index][0]:", yhat_array[test_index][0])
Onefil_lr= np.array(Onefil_lr).reshape(-1, 1)

# %%
print('相关系数: ', np.corrcoef(data[:,0], data[:, 4]))
# a = Onefil_lr/4+Onefil_cnn.reshape(-1, 1)/4+Onefil_svr.reshape(-1, 1)/4+Onefil_bp.reshape(-1, 1)/4
# print(a.shape)
# print("a_Aim:", np.hstack((Onefil_Aim, Onefil_svr.reshape(-1, 1))))
# int('mse: ', mean_squared_error())
print('R2: ', r2_score(Onefil_data[:,3], Onefil_svr.reshape(-1, 1)))
print('mse: ', mean_squared_error(Onefil_data[:,3], Onefil_cnn.reshape(-1, 1)))
# Out:
# 相关系数:  [[ 1.         -0.42117273]
#  [-0.42117273  1.        ]]
# R2:  0.7063834814070289
# mse:  0.5211612390515903

# %%
plt.figure(figsize=(20,10))
plt.plot(Onefil_data[:,4], '-', linewidth=2)
plt.plot(Onefil_lr, '-', linewidth=2)
plt.xticks(fontsize=14);
plt.yticks(fontsize=14);
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 测井曲线

# %%
plt.figure(figsize=(20, 10))
plt.plot(Onefil_data[:,4], '-', linewidth=2)
plt.plot(Onefil_data[:,5], '-', linewidth=2)
plt.xticks(fontsize=14);
plt.yticks(fontsize=14);
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 预测曲线

# %%
fig = plt.figure(figsize=(20,5))
plt.plot(Onefil_data[:,3], '-', linewidth=2, label='Core_value')
plt.plot(Onefil_svr, '-', linewidth=2, label='DT_predict_value')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
fig_1 = plt.figure(figsize=(20, 10))  # 作图画布大小(每循环一次，就会建立新的画布）
ax = fig_1.add_subplot( 5, 1,1)
ax.plot(Onefil_data[:,3], '-', linewidth=2)
ax.plot(Onefil_svr, '-', linewidth=2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(range(0,6,2))
ax = fig_1.add_subplot(5, 1, 2)
ax.plot(Onefil_data[:,3], '-', linewidth=2)
ax.plot(Onefil_dt, '-', linewidth=2)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(range(0,6,2))
ax = fig_1.add_subplot(5, 1, 3)
ax.plot(Onefil_data[:,3], '-', linewidth=2)
ax.plot(Onefil_rf, '-', linewidth=2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(range(0,6,2))
ax = fig_1.add_subplot(5, 1, 4)
ax.plot(Onefil_data[:,3], '-', linewidth=2)
ax.plot(Onefil_bp, '-', linewidth=2)
plt.yticks(range(0,6,2))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax = fig_1.add_subplot(5, 1, 5)
ax.plot(Onefil_data[:,3], '-', linewidth=2)
ax.plot(Onefil_cnn.reshape(-1, 1), '-', linewidth=2)
plt.yticks(range(0,6,2))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     # plt.savefig(r"D:\software\pycharm\PyCharm 1319.3.3\projects\predict_GASV\结果\onewey\图片\两口井3to5\onecon/" + name + ".png")
#     plt.savefig("lab_bp_loocv_carve_predict")

plt.show()

# %% [markdown]
# 散点图

# %%
fig_2 = plt.figure(figsize=(20, 5))
fig_2.add_subplot(1, 3, 1)
plt.scatter(shuffle_data[:,1], shuffle_data[:,4],  s = 16)
plt.scatter(Onefil_data[:,1], Onefil_data[:,4], color = '#FF8C00', s = 14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

fig_2.add_subplot(1, 3, 2)
plt.scatter(shuffle_data[:,0], shuffle_data[:,4], s = 16)
plt.scatter(Onefil_data[:,0], Onefil_data[:,4], color = '#FF8C00',s = 14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

fig_2.add_subplot(1, 3, 3)
plt.scatter(shuffle_RHOB, shuffle_GAS, s = 16)
plt.scatter(Onefil_data[:,2], Onefil_data[:,4], color = '#FF8C00', s = 14)
plt.plot(shuffle_RHOB, shuffle_LR_GAS + 1.6, color = 'black')
plt.plot(shuffle_RHOB, shuffle_LR_GAS - 1.6, color = 'black')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10.]),
#  <a list of 7 Text yticklabel objects>)
